# %%
import googlemaps
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

google_key='AIzaSyDEqZo9y3Up2pKJF3lxt1yqc3EACdEkRqo'
gmaps = googlemaps.Client(key=google_key)
Your_radius = input('Enter the search radius in meter.')
nearby_results = gmaps.places_nearby(location=(43.0383213,-76.1402645),radius = Your_radius,type='restaurant')
nearby_results = nearby_results['results']
restaurant = []
Address = []
Phone_number = []
for nearby_result in nearby_results:
    ID=nearby_result['place_id']
    name=gmaps.place(ID,language='zh-tw')
    restaurant.append(name['result']['name'])
    address = name['result']['address_components'][0]['long_name']+name['result']['address_components'][1]['long_name']+name['result']['address_components'][3]['long_name']+name['result']['address_components'][5]['short_name']
    Address.append(address)
    phone_number = name['result']['formatted_phone_number']
    Phone_number.append(phone_number)

information = pd.DataFrame({'Restaurant':restaurant,'Address':Address,'Phone Number':Phone_number})
information
# Out:
# Enter the search radius in meter.500
#             Restaurant                                   Address  \
# 0         Jimmy John's              103Marshall StreetSyracuseNY
# 1  Faegan's Cafe & Pub          734South Crouse AvenueSyracuseNY
# 2        Varsity Pizza          802South Crouse AvenueSyracuseNY
# 3              Dunkin'          746South Crouse AvenueSyracuseNY
# 4      Good To Go Cafe                725Irving AvenueSyracuseNY
# 5  Varsity Coffee Shop          802South Crouse AvenueSyracuseNY
# 6        Varsity Pizza  Marshall StreetEastsideOnondaga CountyUS
#
#      Phone Number
# 0  (315) 479-7827
# 1  (315) 472-4721
# 2  (315) 478-1235
# 3  (315) 385-4002
# 4  (315) 424-1169
# 5  (315) 476-0515
# 6  (315) 478-1235
